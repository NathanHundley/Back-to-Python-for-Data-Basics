# %% [markdown]
# <h2>Purpose of this notebook is to understand how Pandas works on its own and with other common packages.</h2>

# %%
import pandas as pd

# %% [markdown]
# <h3>Importing data</h3>

# %%
##Pull csv data from folder
data = pd.read_csv('./happiness_with_continent.csv')

# %%
##Pull csv data from website
data = pd.read_csv('https://raw.githubusercontent.com/FBosler/you-datascientist/master/happiness_with_continent.csv')

# %%
##Pulling data from clipboard
pd.read_clipboard(index_col='#First_Column_Name')

# %%
##Other read methods
read_feather
read_fwf
read_gbq
read_hdf
read_html
read_json
read_msgpack
read_parquet
read_pickle
read_sas
read_sql
read_sql_query
read_sql_table
read_stata
read_table

# %% [markdown]
# <h3>Inspecting, sorting, and filtering data</h3>

# %%
#Preview first three rows
data.head(3)
# Out:
#   Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590            7.168690        0.450662
# 1  Afghanistan  2009     4.401778            7.333790        0.552308
# 2  Afghanistan  2010     4.758381            7.386629        0.539075
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.799999                      0.718114    0.177889
# 1                         51.200001                      0.678896    0.200178
# 2                         51.599998                      0.600127    0.134353
#
#    Perceptions of corruption  Positive affect  ...  \
# 0                   0.881686         0.517637  ...
# 1                   0.850035         0.583926  ...
# 2                   0.706766         0.618265  ...
#
#    GINI index (World Bank estimate), average 2000-16  \
# 0                                                NaN
# ...

# %%
#Preview bottom three rows
data.tail(3)
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 1701     Zimbabwe  2016      3.73540            7.538829        0.768425
# 1702     Zimbabwe  2017      3.63830            7.549491        0.754147
# 1703     Zimbabwe  2018      3.61648            7.553395        0.775388
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 1701                         54.400002                      0.732971
# 1702                         55.000000                      0.752826
# 1703                         55.599998                      0.762675
#
#       Generosity  Perceptions of corruption  Positive affect  ...  \
# 1701   -0.068105                   0.723612         0.737636  ...
# 1702   -0.069670                   0.751208         0.806428  ...
# 1703   -0.038384                   0.844209         0.710119  ...
#
#       GINI index (World Bank estimate), average 2000-16  \
# 1701                                              0.432
# ...

# %%
#Preview random three rows
data.sample(3)
# Out:
#         Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 1112           Niger  2016     4.234646            6.821260        0.682828
# 889       Luxembourg  2012     6.964097           11.402052        0.913908
# 1598  United Kingdom  2013     6.918055           10.529394        0.936884
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 1112                         52.500000                      0.701927
# 889                          72.059998                      0.916521
# 1598                         71.540001                      0.905278
#
#       Generosity  Perceptions of corruption  Positive affect  ...  \
# 1112   -0.002667                   0.814494         0.674859  ...
# 889     0.053239                   0.402753         0.815249  ...
# 1598    0.342439                   0.568043         0.775744  ...
#
#       GINI index (World Bank estimate), average 2000-16  \
# ...

# %%
##To see max number of columns and rows
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 8)

# %%
#Shows the number of rows and columns in the dataset
data.shape
# Out:
# (1704, 27)

# %%
#Shows all column names
data.columns
# Out:
# Index(['Country name', 'Year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect',
#        'Confidence in national government', 'Democratic Quality',
#        'Delivery Quality', 'Standard deviation of ladder by country-year',
#        'Standard deviation/Mean of ladder by country-year',
#        'GINI index (World Bank estimate)',
#        'GINI index (World Bank estimate), average 2000-16',
#        'gini of household income reported in Gallup, by wp5-year',
#        'Most people can be trusted, Gallup',
#        'Most people can be trusted, WVS round 1981-1984',
#        'Most people can be trusted, WVS round 1989-1993',
#        'Most people can be trusted, WVS round 1994-1998',
#        'Most people can be trusted, WVS round 1999-2004',
#        'Most people can be trusted, WVS round 2005-2009',
# ...

# %%
#Shows types of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 27 columns):
# Country name                                                1704 non-null object
# Year                                                        1704 non-null int64
# Life Ladder                                                 1704 non-null float64
# Log GDP per capita                                          1676 non-null float64
# Social support                                              1691 non-null float64
# Healthy life expectancy at birth                            1676 non-null float64
# Freedom to make life choices                                1675 non-null float64
# Generosity                                                  1622 non-null float64
# Perceptions of corruption                                   1608 non-null float64
# Positive affect                                             1685 non-null float64
# ...

# %%
#Show data types
data.dtypes.value_counts()
# Out:
# float64    24
# int64       1
# object      1
# dtype: int64

# %%
#Copy dataframes
df = data.copy()

# %%
#Shows descriptives of data
data.describe()
# Out:
#               Year  Life Ladder  Log GDP per capita  Social support  \
# count  1704.000000  1704.000000         1676.000000     1691.000000
# mean   2012.332160     5.437155            9.222456        0.810570
# std       3.688072     1.121149            1.185794        0.119210
# min    2005.000000     2.661718            6.457201        0.290184
# 25%    2009.000000     4.610970            8.304428        0.747512
# 50%    2012.000000     5.339557            9.406206        0.833098
# 75%    2015.000000     6.273522           10.193060        0.904432
# max    2018.000000     8.018934           11.770276        0.987343
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       1676.000000                   1675.000000
# mean                          63.111971                      0.733829
# std                            7.583622                      0.144115
# min                           32.299999                      0.257534
# ...

# %%
#Sort data values by one column
data.sort_values(by='Year')
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 130       Belgium  2005     7.262290           10.591697        0.934875
# 397       Denmark  2005     8.018934           10.704770        0.972372
# 844       Lebanon  2005     5.491245            9.414857        0.796278
# 624       Hungary  2005     5.193933           10.019172        0.929628
# ...           ...   ...          ...                 ...             ...
# 568        Greece  2018     5.409289           10.132058        0.793501
# 1217  Philippines  2018     5.869173            8.985703        0.845803
# 518        Gambia  2018     4.922099            7.376554        0.684800
# 1703     Zimbabwe  2018     3.616480            7.553395        0.775388
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 130                          69.900002                      0.923843
# 397                          69.599998                      0.971135
# ...

# %%
#Sort data values by two columns
#Sorts based on order of the values
data.sort_values(by=['Year','Country name'])
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 59      Australia  2005     7.340688           10.569470        0.967892
# 130       Belgium  2005     7.262290           10.591697        0.934875
# 192        Brazil  2005     6.636771            9.417240        0.882923
# 258        Canada  2005     7.418048           10.608347        0.961552
# ...           ...   ...          ...                 ...             ...
# 1667      Vietnam  2018     5.295547            8.783416        0.831945
# 1678        Yemen  2018     3.057514                 NaN        0.789422
# 1690       Zambia  2018     4.041488            8.223958        0.717720
# 1703     Zimbabwe  2018     3.616480            7.553395        0.775388
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 59                           71.400002                      0.934973
# 130                          69.900002                      0.923843
# ...

# %%
#Sort by two columns descending first and ascending second
data.sort_values(
  by=['Year','Country name'], 
  ascending=[False,True]
)
# Out:
#         Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 10       Afghanistan  2018     2.694303            7.494588        0.507516
# 21           Albania  2018     5.004403            9.412399        0.683592
# 28           Algeria  2018     5.043086            9.557952        0.798651
# 45         Argentina  2018     5.792797            9.809972        0.899912
# ...              ...   ...          ...                 ...             ...
# 1432          Sweden  2005     7.376316           10.626856        0.951470
# 1532          Turkey  2005     4.718734            9.699514        0.819936
# 1591  United Kingdom  2005     6.983557           10.522983        0.978840
# 1642       Venezuela  2005     7.169621            9.612341        0.955278
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 10                           52.599998                      0.373536
# ...

# %%
#Selecting one column
data['Year'].head(3)
# Out:
# 0    2008
# 1    2009
# 2    2010
# Name: Year, dtype: int64

# %%
#Selecting multiple columns
#Double brackets result in a data frame
data[['Country name','Year','Life Ladder']].sample(3)
# Out:
#      Country name  Year  Life Ladder
# 1225       Poland  2014     5.750282
# 858       Lesotho  2016     3.808205
# 296         Chile  2013     6.740154

# %%
#Using iloc to select rows and columns
#Follows format data.iloc[row_number, col_number]
#Selects rows 903 through 906 and columns zero through three
data.iloc[903:907,0:3]
# Out:
#     Country name  Year  Life Ladder
# 903    Macedonia  2015     4.975590
# 904    Macedonia  2016     5.345746
# 905    Macedonia  2017     5.233867
# 906    Macedonia  2018     5.239835

# %%
#Set indexing variable for the dataset
data.set_index('Country name', inplace=True)
data.sample(3)
# Out:
#               Year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# Sierra Leone  2013     4.514291            7.411630        0.708427
# Ghana         2014     3.860351            8.260648        0.651469
# Slovenia      2011     6.035964           10.268294        0.931166
#
#               Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# Sierra Leone                         45.160000                      0.719511
# Ghana                                55.619999                      0.676916
# Slovenia                             69.400002                      0.907441
#
#               Generosity  Perceptions of corruption  Positive affect  \
# Country name
# Sierra Leone   -0.064522                   0.855863         0.520902
# Ghana           0.007108                   0.912682         0.696155
# Slovenia       -0.027568                   0.893134         0.651521
#
# ...

# %%
data.index
# Out:
# Index(['Afghanistan', 'Afghanistan', 'Afghanistan', 'Afghanistan',
#        'Afghanistan', 'Afghanistan', 'Afghanistan', 'Afghanistan',
#        'Afghanistan', 'Afghanistan',
#        ...
#        'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe',
#        'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe'],
#       dtype='object', name='Country name', length=1704)

# %%
#Selecting row(s) by one index label
data.loc['United States']
# Out:
#                Year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# United States  2006     7.181794           10.831686        0.964572
# United States  2007     7.512688           10.839805             NaN
# United States  2008     7.280386           10.827426        0.952587
# United States  2009     7.158032           10.790511        0.911794
# ...             ...          ...                 ...             ...
# United States  2015     6.863947           10.878154        0.903571
# United States  2016     6.803600           10.885554        0.896751
# United States  2017     6.991759           10.900906        0.921003
# United States  2018     6.882685           10.922465        0.903856
#
#                Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# United States                         68.059998                      0.911496
# United States                         68.220001                      0.871904
# ...

# %%
#Selecting Life Ladder column by the index variable of United States
data.loc['United States', 'Life Ladder']
# Out:
# Country name
# United States    7.181794
# United States    7.512688
# United States    7.280386
# United States    7.158032
#                    ...
# United States    6.863947
# United States    6.803600
# United States    6.991759
# United States    6.882685
# Name: Life Ladder, Length: 13, dtype: float64

# %%
data.loc[['United States', 'Germany']].sample(3)
# Out:
#                Year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# United States  2007     7.512688           10.839805             NaN
# United States  2014     7.151114           10.857497        0.902097
# United States  2011     7.115139           10.815644        0.921705
#
#                Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# United States                         68.220001                      0.871904
# United States                         68.620003                      0.866077
# United States                         68.680000                      0.863202
#
#                Generosity  Perceptions of corruption  Positive affect  \
# Country name
# United States    0.188272                   0.633035         0.828503
# United States    0.212869                   0.702267         0.834294
# United States    0.152239                   0.696926         0.836360
#
# ...

# %%
#Selecting rows and columns by multiple index labels
data.loc[
    ['Germany', 'United States'],
    ['Year','Life Ladder']
]
# Out:
#                Year  Life Ladder
# Country name
# Germany        2005     6.619550
# Germany        2007     6.416820
# Germany        2008     6.521790
# Germany        2009     6.641493
# ...             ...          ...
# United States  2015     6.863947
# United States  2016     6.803600
# United States  2017     6.991759
# United States  2018     6.882685
#
# [26 rows x 2 columns]

# %%
#Selecting a range of values based on index
data.loc[
    'Denmark':'Germany',
    ['Year','Life Ladder']
].sample(3)
# Out:
#               Year  Life Ladder
# Country name
# Georgia       2014     4.287508
# El Salvador   2012     5.934371
# Egypt         2005     5.167754

# %%
#Boolean check on the data
data['Life Ladder']>4
# Out:
# Country name
# Afghanistan    False
# Afghanistan     True
# Afghanistan     True
# Afghanistan    False
#                ...
# Zimbabwe       False
# Zimbabwe       False
# Zimbabwe       False
# Zimbabwe       False
# Name: Life Ladder, Length: 1704, dtype: bool

# %%
#Alternative, selecting only those cases greater than four
condition = data['Life Ladder'] > 4
data.loc[condition]
# Out:
#               Year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# Afghanistan   2009     4.401778            7.333790        0.552308
# Afghanistan   2010     4.758381            7.386629        0.539075
# Afghanistan   2016     4.220169            7.497038        0.559072
# Albania       2007     4.634252            9.077331        0.821372
# ...            ...          ...                 ...             ...
# Zimbabwe      2011     4.845642            7.418864        0.864694
# Zimbabwe      2012     4.955101            7.534424        0.896476
# Zimbabwe      2013     4.690188            7.565154        0.799274
# Zimbabwe      2014     4.184451            7.562753        0.765839
#
#               Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# Afghanistan                          51.200001                      0.678896
# Afghanistan                          51.599998                      0.600127
# ...

# %%
#Applying multiple conditions
life_condition = data['Life Ladder'] > 4
year_condition = data['Year'] > 2014
gen_condition = data['Generosity'] > .2

data.loc[life_condition & year_condition & gen_condition]
#| used for or, & for and
# Out:
#                Year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# Australia      2015     7.309061           10.690199        0.951862
# Australia      2016     7.250080           10.703098        0.942334
# Australia      2017     7.257038           10.706581        0.949958
# Bhutan         2015     5.082129            8.954588        0.847574
# ...             ...          ...                 ...             ...
# United States  2015     6.863947           10.878154        0.903571
# Uzbekistan     2015     5.972364            8.648263        0.968225
# Uzbekistan     2016     5.892539            8.705982        0.945102
# Uzbekistan     2018     6.205460            8.773365        0.920821
#
#                Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# Australia                             72.699997                      0.921871
# Australia                             73.000000                      0.922316
# ...

# %%
#Applying lambda conditions for sorting data
cond_year = data['Year'].apply(lambda x: x%3 == 0)
cond_america = data['Continent'].apply(lambda x: 'America' in x)

data[cond_year & cond_america]
# Out:
#               Year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# Argentina     2007     6.073158            9.792596        0.862206
# Argentina     2010     6.441067            9.836924        0.926799
# Argentina     2013     6.582260            9.877256        0.909874
# Argentina     2016     6.427221            9.830088        0.882819
# ...            ...          ...                 ...             ...
# Uruguay       2016     6.171485            9.908158        0.900381
# Venezuela     2010     7.478455            9.713838        0.931576
# Venezuela     2013     6.552796            9.779354        0.896301
# Venezuela     2016     4.041115            9.534059        0.901949
#
#               Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# Argentina                            66.940002                      0.652833
# Argentina                            67.300003                      0.730258
# ...

# %%
#combining columns
data['Year'] + data['Life Ladder']
# Out:
# Country name
# Afghanistan    2011.723590
# Afghanistan    2013.401778
# Afghanistan    2014.758381
# Afghanistan    2014.831719
#                   ...
# Zimbabwe       2018.703191
# Zimbabwe       2019.735400
# Zimbabwe       2020.638300
# Zimbabwe       2021.616480
# Length: 1704, dtype: float64

# %%
#combining columns with strings operations
data['Continent'] + '_' + data['Year'].astype(str)
# Out:
# Country name
# Afghanistan      Asia_2008
# Afghanistan      Asia_2009
# Afghanistan      Asia_2010
# Afghanistan      Asia_2011
#                   ...
# Zimbabwe       Africa_2015
# Zimbabwe       Africa_2016
# Zimbabwe       Africa_2017
# Zimbabwe       Africa_2018
# Length: 1704, dtype: object

# %%
#Grouping by commands
#Reports highest Life Ladder value for each country
data.groupby(['Country name'])['Life Ladder'].max()
# Out:
# Country name
# Afghanistan    4.758381
# Albania        5.867422
# Algeria        6.354898
# Angola         5.589001
#                  ...
# Vietnam        5.767344
# Yemen          4.809259
# Zambia         5.260361
# Zimbabwe       4.955101
# Name: Life Ladder, Length: 165, dtype: float64

# %%
#Want to find the country with the highest Life Ladder by year
data.groupby(['Year'])['Life Ladder'].idxmax()
# Out:
# Year
# 2005    Denmark
# 2006    Finland
# 2007    Denmark
# 2008    Denmark
#          ...
# 2015     Norway
# 2016    Finland
# 2017    Finland
# 2018    Finland
# Name: Life Ladder, Length: 14, dtype: object

# %%
#Want to find the country with the highest Life Ladder by year and continent
data.groupby(['Year','Continent'])['Life Ladder'].idxmax()
# Out:
# Year  Continent
# 2005  Africa                  Egypt
#       Asia             Saudi Arabia
#       Europe                Denmark
#       North America          Canada
#                            ...
# 2018  Europe                Finland
#       North America          Canada
#       Oceania           New Zealand
#       South America           Chile
# Name: Life Ladder, Length: 83, dtype: object

# %%
#Shows unique values in column
data['Continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'South America', 'Oceania',
#        'North America'], dtype=object)

# %%
#Shows distribution of value counts
data['Continent'].value_counts()
# Out:
# Asia             525
# Europe           450
# Africa           420
# North America    154
# South America    131
# Oceania           24
# Name: Continent, dtype: int64

# %%
#Shows distribution of value counts
#normalize = True if you want to check the frequency instead of counts
data['Continent'].value_counts(normalize=True)
# Out:
# Asia             0.308099
# Europe           0.264085
# Africa           0.246479
# North America    0.090376
# South America    0.076878
# Oceania          0.014085
# Name: Continent, dtype: float64

# %%
#Shows distribution of value counts
#dropna = False if you want to include missing values in the stats
data['Continent'].value_counts(dropna=False)
# Out:
# Asia             525
# Europe           450
# Africa           420
# North America    154
# South America    131
# Oceania           24
# Name: Continent, dtype: int64

# %%
#Counting number of missing values
import numpy as np

data['num_missing'] = data[['Continent','Life Ladder', 'Year']].isnull().sum(axis=1)
data['num_missing']
# Out:
# Country name
# Afghanistan    0
# Afghanistan    0
# Afghanistan    0
# Afghanistan    0
#               ..
# Zimbabwe       0
# Zimbabwe       0
# Zimbabwe       0
# Zimbabwe       0
# Name: num_missing, Length: 1704, dtype: int64

# %%
#Selecting rows with specific IDs
data_filter = data['Continent'].isin(['Asia','Europe'])
data[data_filter]
# Out:
#               Year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# Afghanistan   2008     3.723590            7.168690        0.450662
# Afghanistan   2009     4.401778            7.333790        0.552308
# Afghanistan   2010     4.758381            7.386629        0.539075
# Afghanistan   2011     3.831719            7.415019        0.521104
# ...            ...          ...                 ...             ...
# Yemen         2015     2.982674            7.744412        0.668683
# Yemen         2016     3.825631            7.299221        0.775407
# Yemen         2017     3.253560                 NaN        0.789555
# Yemen         2018     3.057514                 NaN        0.789422
#
#               Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# Afghanistan                          50.799999                      0.718114
# Afghanistan                          51.200001                      0.678896
# ...

# %%
#Creating cut groups, 5% into group 1, 5-20% in group 2, 20-50% in group 3, and bottom 50% in group 4
import numpy as np
cutpoints = [np.percentile(data['Life Ladder'], i) for i in [50, 80, 95]]
data['group'] = 1

for i in range(3):
    data['group'] = data['group'] + (data['Life Ladder'] <= cutpoints[i])

# %%
data['group'].value_counts()
# Out:
# 4    852
# 3    511
# 2    255
# 1     86
# Name: group, dtype: int64

# %%
#Merge data similar to SQL join
data.merge(other_Data, on=['column_1','column_2'])

# %% [markdown]
# <h3>Analyses using pandas</h3>

# %%
#columnwise max
data.max()
# Out:
# Year                                                        2018
# Life Ladder                                              8.01893
# Log GDP per capita                                       11.7703
# Social support                                          0.987343
#                                                        ...
# Most people can be trusted, WVS round 1999-2004         0.637185
# Most people can be trusted, WVS round 2005-2009         0.737305
# Most people can be trusted, WVS round 2010-2014         0.661757
# Continent                                          South America
# Length: 26, dtype: object

# %%
#rowwise max
data.max(axis=1)
# Out:
# Country name
# Afghanistan    2008.0
# Afghanistan    2009.0
# Afghanistan    2010.0
# Afghanistan    2011.0
#                 ...
# Zimbabwe       2015.0
# Zimbabwe       2016.0
# Zimbabwe       2017.0
# Zimbabwe       2018.0
# Length: 1704, dtype: float64

# %%
#columnwise min
data.min()
# Out:
# Year                                                    2005
# Life Ladder                                          2.66172
# Log GDP per capita                                    6.4572
# Social support                                      0.290184
#                                                      ...
# Most people can be trusted, WVS round 1999-2004    0.0758722
# Most people can be trusted, WVS round 2005-2009    0.0382419
# Most people can be trusted, WVS round 2010-2014    0.0315181
# Continent                                             Africa
# Length: 26, dtype: object

# %%
#rowwise min
data.min(axis=1)
# Out:
# Country name
# Afghanistan   -1.929690
# Afghanistan   -2.044093
# Afghanistan   -1.991810
# Afghanistan   -1.919018
#                  ...
# Zimbabwe      -1.357514
# Zimbabwe      -1.374650
# Zimbabwe      -1.350867
# Zimbabwe      -0.038384
# Length: 1704, dtype: float64

# %%
#columnwise sum
data.sum()
# Out:
# Year                                                                                         3429014
# Life Ladder                                                                                  9264.91
# Log GDP per capita                                                                           15456.8
# Social support                                                                               1370.67
#                                                                          ...
# Most people can be trusted, WVS round 1999-2004                                              131.623
# Most people can be trusted, WVS round 2005-2009                                              166.532
# Most people can be trusted, WVS round 2010-2014                                              159.358
# Continent                                          AsiaAsiaAsiaAsiaAsiaAsiaAsiaAsiaAsiaAsiaAsiaEu...
# Length: 26, dtype: object

# %%
#columnwise mean
data.mean()
# Out:
# Year                                               2012.332160
# Life Ladder                                           5.437155
# Log GDP per capita                                    9.222456
# Social support                                        0.810570
#                                                       ...
# Most people can be trusted, WVS round 1994-1998       0.249574
# Most people can be trusted, WVS round 1999-2004       0.268070
# Most people can be trusted, WVS round 2005-2009       0.264336
# Most people can be trusted, WVS round 2010-2014       0.237493
# Length: 25, dtype: float64

# %%
#columnwise median
data.median()
# Out:
# Year                                               2012.000000
# Life Ladder                                           5.339557
# Log GDP per capita                                    9.406206
# Social support                                        0.833098
#                                                       ...
# Most people can be trusted, WVS round 1994-1998       0.229924
# Most people can be trusted, WVS round 1999-2004       0.232000
# Most people can be trusted, WVS round 2005-2009       0.198380
# Most people can be trusted, WVS round 2010-2014       0.193531
# Length: 25, dtype: float64

# %%
#columnwise quantile
data.quantile()
# Out:
# Year                                               2012.000000
# Life Ladder                                           5.339557
# Log GDP per capita                                    9.406206
# Social support                                        0.833098
#                                                       ...
# Most people can be trusted, WVS round 1994-1998       0.229924
# Most people can be trusted, WVS round 1999-2004       0.232000
# Most people can be trusted, WVS round 2005-2009       0.198380
# Most people can be trusted, WVS round 2010-2014       0.193531
# Name: 0.5, Length: 25, dtype: float64

# %%
#idxmin/idxman return the index of the row where the first min/max is found
data.iloc[:,:-1].idxmax()
# Out:
# Year                                               Afghanistan
# Life Ladder                                            Denmark
# Log GDP per capita                                       Qatar
# Social support                                     New Zealand
#                                                       ...
# Most people can be trusted, WVS round 1994-1998         Norway
# Most people can be trusted, WVS round 1999-2004         Sweden
# Most people can be trusted, WVS round 2005-2009         Norway
# Most people can be trusted, WVS round 2010-2014    Netherlands
# Length: 25, dtype: object

# %%
#Transforming variables into a new column
level_map = {'Asia':1, 'Europe':2, 'Africa':3, 'South America':4, 'Oceania':5, 'North America':6}
data['Continent_Mapping'] = data['Continent'].map(level_map)
data['Continent_Mapping'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6], dtype=int64)

# %%
#Correlation matrix
data.corr()
# Out:
#                                                      Year  Life Ladder  \
# Year                                             1.000000    -0.007075
# Life Ladder                                     -0.007075     1.000000
# Log GDP per capita                               0.043336     0.779064
# Social support                                  -0.046008     0.702461
# ...                                                   ...          ...
# Most people can be trusted, WVS round 2010-2014 -0.000484     0.348629
# Continent_Mapping                               -0.011907     0.129376
# num_missing                                           NaN          NaN
# group                                            0.007136    -0.903096
#
#                                                  Log GDP per capita  \
# Year                                                       0.043336
# Life Ladder                                                0.779064
# ...

# %% [markdown]
# <h3>Basic Plotting with Pandas</h3>

# %%
pd.plotting.scatter_matrix(data[['Year','Life Ladder','Log GDP per capita']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000198069D81D0>,
# ...
#       dtype=object)

# %%
# %matplotlib inline
data['Life Ladder'].plot()

# %%
#histogram
data['Life Ladder'].hist()

# %%
#box plot
data[['Life Ladder','Log GDP per capita']].plot.box()

# %% [markdown]
# <h3>Exporting files</h3>

# %%
#Preview csv printing
print(data[:3].to_csv())
# Out:
# Country name,Year,Life Ladder,Log GDP per capita,Social support,Healthy life expectancy at birth,Freedom to make life choices,Generosity,Perceptions of corruption,Positive affect,Negative affect,Confidence in national government,Democratic Quality,Delivery Quality,Standard deviation of ladder by country-year,Standard deviation/Mean of ladder by country-year,GINI index (World Bank estimate),"GINI index (World Bank estimate), average 2000-16","gini of household income reported in Gallup, by wp5-year","Most people can be trusted, Gallup","Most people can be trusted, WVS round 1981-1984","Most people can be trusted, WVS round 1989-1993","Most people can be trusted, WVS round 1994-1998","Most people can be trusted, WVS round 1999-2004","Most people can be trusted, WVS round 2005-2009","Most people can be trusted, WVS round 2010-2014",Continent,Continent_Mapping,num_missing,group
# ...

# %%
data.to_csv('C:/Users/nhundley/Desktop/data.csv')
